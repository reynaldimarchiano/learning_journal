# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('nbaallelo.csv')
df
# Out:
#         gameorder       game_id lg_id  _iscopy  year_id  date_game  \
# 0               1  194611010TRH   NBA        0     1947  11/1/1946
# 1               1  194611010TRH   NBA        1     1947  11/1/1946
# 2               2  194611020CHS   NBA        0     1947  11/2/1946
# 3               2  194611020CHS   NBA        1     1947  11/2/1946
# 4               3  194611020DTF   NBA        0     1947  11/2/1946
# ...           ...           ...   ...      ...      ...        ...
# 126309      63155  201506110CLE   NBA        0     2015  6/11/2015
# 126310      63156  201506140GSW   NBA        0     2015  6/14/2015
# 126311      63156  201506140GSW   NBA        1     2015  6/14/2015
# 126312      63157  201506170CLE   NBA        0     2015  6/16/2015
# 126313      63157  201506170CLE   NBA        1     2015  6/16/2015
#
#         seasongame  is_playoffs team_id    fran_id  pts      elo_i      elo_n  \
# 0                1            0     TRH    Huskies   66  1300.0000  1293.2767
# ...

# %%
df.shape
# Out:
# (126314, 23)

# %%
#setting jumlah kolom yang ditampilkan
pd.set_option('display.max.columns',None)

# %%
df.head()
# Out:
#    gameorder       game_id lg_id  _iscopy  year_id  date_game  seasongame  \
# 0          1  194611010TRH   NBA        0     1947  11/1/1946           1
# 1          1  194611010TRH   NBA        1     1947  11/1/1946           1
# 2          2  194611020CHS   NBA        0     1947  11/2/1946           1
# 3          2  194611020CHS   NBA        1     1947  11/2/1946           2
# 4          3  194611020DTF   NBA        0     1947  11/2/1946           1
#
#    is_playoffs team_id  fran_id  pts      elo_i      elo_n  win_equiv opp_id  \
# 0            0     TRH  Huskies   66  1300.0000  1293.2767  40.294830    NYK
# 1            0     NYK   Knicks   68  1300.0000  1306.7233  41.705170    TRH
# 2            0     CHS    Stags   63  1300.0000  1309.6521  42.012257    NYK
# 3            0     NYK   Knicks   47  1306.7233  1297.0712  40.692783    CHS
# 4            0     DTF  Falcons   33  1300.0000  1279.6189  38.864048    WSC
#
# ...

# %%
df.tail()
# Out:
#         gameorder       game_id lg_id  _iscopy  year_id  date_game  \
# 126309      63155  201506110CLE   NBA        0     2015  6/11/2015
# 126310      63156  201506140GSW   NBA        0     2015  6/14/2015
# 126311      63156  201506140GSW   NBA        1     2015  6/14/2015
# 126312      63157  201506170CLE   NBA        0     2015  6/16/2015
# 126313      63157  201506170CLE   NBA        1     2015  6/16/2015
#
#         seasongame  is_playoffs team_id    fran_id  pts      elo_i      elo_n  \
# 126309         100            1     CLE  Cavaliers   82  1723.4149  1704.3949
# 126310         102            1     GSW   Warriors  104  1809.9791  1813.6349
# 126311         101            1     CLE  Cavaliers   91  1704.3949  1700.7391
# 126312         102            1     CLE  Cavaliers   97  1700.7391  1692.0859
# 126313         103            1     GSW   Warriors  105  1813.6349  1822.2881
#
#         win_equiv opp_id   opp_fran  opp_pts  opp_elo_i  opp_elo_n  \
# ...

# %%
df.sample(8)
# Out:
#         gameorder       game_id lg_id  _iscopy  year_id  date_game  \
# 71765       35883  199312060SEA   NBA        0     1994  12/6/1993
# 39562       19782  197803280CHI   NBA        0     1978  3/28/1978
# 16465        8233  196802070INA   ABA        0     1968   2/7/1968
# 8214         4108  195801270LAL   NBA        0     1958  1/27/1958
# 116566      58284  201201110DEN   NBA        1     2012  1/11/2012
# 37291       18646  197702220DEN   NBA        0     1977  2/22/1977
# 59537       29769  198804210BOS   NBA        0     1988  4/21/1988
# 21132       10567  197003130LAL   NBA        0     1970  3/13/1970
#
#         seasongame  is_playoffs team_id  fran_id  pts      elo_i      elo_n  \
# 71765           15            0     SEA  Thunder  103  1658.8345  1660.0826
# 39562           77            0     CHI    Bulls  105  1461.2886  1436.2301
# 16465           58            0     INA   Pacers  106  1304.3185  1306.6514
# ...

# %% [markdown]
# ## Data Overview

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 126314 entries, 0 to 126313
# Data columns (total 23 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   gameorder      126314 non-null  int64
#  1   game_id        126314 non-null  object
#  2   lg_id          126314 non-null  object
#  3   _iscopy        126314 non-null  int64
#  4   year_id        126314 non-null  int64
#  5   date_game      126314 non-null  object
#  6   seasongame     126314 non-null  int64
#  7   is_playoffs    126314 non-null  int64
#  8   team_id        126314 non-null  object
#  9   fran_id        126314 non-null  object
#  10  pts            126314 non-null  int64
#  11  elo_i          126314 non-null  float64
#  12  elo_n          126314 non-null  float64
#  13  win_equiv      126314 non-null  float64
#  14  opp_id         126314 non-null  object
#  15  opp_fran       126314 non-null  object
#  16  opp_pts        126314 non-null  int64
# ...

# %%
df.describe().T
# Out:
#                 count          mean           std          min           25%  \
# gameorder    126314.0  31579.000000  18231.927643     1.000000  15790.000000
# _iscopy      126314.0      0.500000      0.500002     0.000000      0.000000
# year_id      126314.0   1988.200374     17.582309  1947.000000   1975.000000
# seasongame   126314.0     43.533733     25.375178     1.000000     22.000000
# is_playoffs  126314.0      0.063857      0.244499     0.000000      0.000000
# pts          126314.0    102.729982     14.814845     0.000000     93.000000
# elo_i        126314.0   1495.236055    112.139945  1091.644500   1417.237975
# elo_n        126314.0   1495.236055    112.461687  1085.774400   1416.994900
# win_equiv    126314.0     41.707889     10.627332    10.152501     34.103035
# opp_pts      126314.0    102.729982     14.814845     0.000000     93.000000
# opp_elo_i    126314.0   1495.236055    112.139945  1091.644500   1417.237975
# ...

# %% [markdown]
# # Data Exploration

# %%
df.head(2)
# Out:
#    gameorder       game_id lg_id  _iscopy  year_id  date_game  seasongame  \
# 0          1  194611010TRH   NBA        0     1947  11/1/1946           1
# 1          1  194611010TRH   NBA        1     1947  11/1/1946           1
#
#    is_playoffs team_id  fran_id  pts   elo_i      elo_n  win_equiv opp_id  \
# 0            0     TRH  Huskies   66  1300.0  1293.2767   40.29483    NYK
# 1            0     NYK   Knicks   68  1300.0  1306.7233   41.70517    TRH
#
#   opp_fran  opp_pts  opp_elo_i  opp_elo_n game_location game_result  forecast  \
# 0   Knicks       68     1300.0  1306.7233             H           L  0.640065
# 1  Huskies       66     1300.0  1293.2767             A           W  0.359935
#
#   notes
# 0   NaN
# 1   NaN

# %%
df[['team_id','fran_id','pts']] #kalo mau banyak kolom, jadiin list pake tanda double []
# Out:
#        team_id    fran_id  pts
# 0          TRH    Huskies   66
# 1          NYK     Knicks   68
# 2          CHS      Stags   63
# 3          NYK     Knicks   47
# 4          DTF    Falcons   33
# ...        ...        ...  ...
# 126309     CLE  Cavaliers   82
# 126310     GSW   Warriors  104
# 126311     CLE  Cavaliers   91
# 126312     CLE  Cavaliers   97
# 126313     GSW   Warriors  105
#
# [126314 rows x 3 columns]

# %%
df['fran_id'].unique()
# Out:
# array(['Huskies', 'Knicks', 'Stags', 'Falcons', 'Capitols', 'Celtics',
#        'Steamrollers', 'Ironmen', 'Bombers', 'Rebels', 'Warriors',
#        'Baltimore', 'Jets', 'Pistons', 'Lakers', 'Kings', 'Hawks',
#        'Denver', 'Olympians', 'Redskins', 'Waterloo', 'Packers', 'Sixers',
#        'Wizards', 'Bulls', 'Thunder', 'Squires', 'Stars', 'Rockets',
#        'Colonels', 'Pacers', 'Nuggets', 'Spurs', 'Spirits', 'Sounds',
#        'Floridians', 'Nets', 'Condors', 'Bucks', 'Suns', 'Clippers',
#        'Cavaliers', 'Trailblazers', 'Sails', 'Jazz', 'Mavericks',
#        'Pelicans', 'Heat', 'Timberwolves', 'Magic', 'Grizzlies',
#        'Raptors', 'Hornets'], dtype=object)

# %%
df['fran_id'].value_counts().head(5)
# Out:
# Lakers      6024
# Celtics     5997
# Knicks      5769
# Warriors    5657
# Pistons     5650
# Name: fran_id, dtype: int64

# %%
df['team_id'].value_counts().head(5)
# Out:
# BOS    5997
# NYK    5769
# LAL    5078
# DET    4985
# PHI    4533
# Name: team_id, dtype: int64

# %% [markdown]
# ada inkonsistensi dari value countsnya

# %%
df.loc[df['fran_id']=='Lakers',['team_id','fran_id']]
# Out:
#        team_id fran_id
# 1136       MNL  Lakers
# 1152       MNL  Lakers
# 1159       MNL  Lakers
# 1170       MNL  Lakers
# 1183       MNL  Lakers
# ...        ...     ...
# 126016     LAL  Lakers
# 126052     LAL  Lakers
# 126086     LAL  Lakers
# 126115     LAL  Lakers
# 126137     LAL  Lakers
#
# [6024 rows x 2 columns]

# %%
df.loc[df['fran_id']== 'Falcons',['pts']] #untuk nampilin dataframe nya
df.loc[df['fran_id']== 'Falcons',['pts']].mean() #untuk cari rata2 jadi pts
# Out:
#      pts
# 4     33
# 17    49
# 25    71
# 29    69
# 42    68
# 56    70
# 63    57
# 71    53
# 85    54
# 93    68
# 100   66
# 117   68
# 127   57
# 132   47
# 138   57
# 145   65
# 160   64
# 167   66
# 176   66
# 178   66
# 189   66
# 202   49
# 221   92
# 232   51
# 244   48
# 258   62
# 268   50
# 280   61
# 282   80
# 298   58
# 315   68
# 327   74
# 338   57
# 345   47
# 359   55
# 367   66
# 377   73
# 401   65
# 409   46
# 422   64
# 432   74
# 440   84
# 465   58
# 468   59
# 474   51
# 480   76
# 503   61
# 515   68
# 531   74
# 548   67
# 551   65
# 563   61
# 579   81
# 596   61
# 600   59
# 610   75
# 620   85
# 627   63
# 636   63
# 648   66

# %% [markdown]
# # QUERY

# %%
df.head(3)
# Out:
#    gameorder       game_id lg_id  _iscopy  year_id  date_game  seasongame  \
# 0          1  194611010TRH   NBA        0     1947  11/1/1946           1
# 1          1  194611010TRH   NBA        1     1947  11/1/1946           1
# 2          2  194611020CHS   NBA        0     1947  11/2/1946           1
#
#    is_playoffs team_id  fran_id  pts   elo_i      elo_n  win_equiv opp_id  \
# 0            0     TRH  Huskies   66  1300.0  1293.2767  40.294830    NYK
# 1            0     NYK   Knicks   68  1300.0  1306.7233  41.705170    TRH
# 2            0     CHS    Stags   63  1300.0  1309.6521  42.012257    NYK
#
#   opp_fran  opp_pts  opp_elo_i  opp_elo_n game_location game_result  forecast  \
# 0   Knicks       68  1300.0000  1306.7233             H           L  0.640065
# 1  Huskies       66  1300.0000  1293.2767             A           W  0.359935
# 2   Knicks       47  1306.7233  1297.0712             H           W  0.631101
#
#   notes
# 0   NaN
# 1   NaN
# 2   NaN

# %%
df[df['year_id']>2012]
# Out:
#         gameorder       game_id lg_id  _iscopy  year_id   date_game  \
# 118426      59214  201210300CLE   NBA        1     2013  10/30/2012
# 118427      59214  201210300CLE   NBA        0     2013  10/30/2012
# 118428      59215  201210300LAL   NBA        0     2013  10/30/2012
# 118429      59215  201210300LAL   NBA        1     2013  10/30/2012
# 118430      59216  201210300MIA   NBA        1     2013  10/30/2012
# ...           ...           ...   ...      ...      ...         ...
# 126309      63155  201506110CLE   NBA        0     2015   6/11/2015
# 126310      63156  201506140GSW   NBA        0     2015   6/14/2015
# 126311      63156  201506140GSW   NBA        1     2015   6/14/2015
# 126312      63157  201506170CLE   NBA        0     2015   6/16/2015
# 126313      63157  201506170CLE   NBA        1     2015   6/16/2015
#
#         seasongame  is_playoffs team_id    fran_id  pts      elo_i      elo_n  \
# ...

# %%
df[(df['year_id']>2010) & (df['fran_id']=='Warriors') & (df['pts'] >100 )&(df['game_result'] == 'W')



    ][['year_id','fran_id','pts', 'opp_pts', 'opp_fran','game_result']]  #query dengan banyak kondisi

    #sampe W itu query filternya
    #[]kedua itu buat nampilin kolom apa aja
# Out:
#         year_id   fran_id  pts  opp_pts   opp_fran game_result
# 113668     2011  Warriors  132      128    Rockets           W
# 113700     2011  Warriors  109       91   Clippers           W
# 113767     2011  Warriors  115      109  Grizzlies           W
# 113853     2011  Warriors  109      102    Raptors           W
# 113874     2011  Warriors  122      117     Knicks           W
# ...         ...       ...  ...      ...        ...         ...
# 126301     2015  Warriors  104       90    Rockets           W
# 126303     2015  Warriors  108      100  Cavaliers           W
# 126308     2015  Warriors  103       82  Cavaliers           W
# 126310     2015  Warriors  104       91  Cavaliers           W
# 126313     2015  Warriors  105       97  Cavaliers           W
#
# [193 rows x 6 columns]

# %%
df[(df['is_playoffs']==1)& (df['fran_id']=='Lakers') & (df['game_location'] == 'H') & (df['year_id']>1970)]
# Out:
#         gameorder       game_id lg_id  _iscopy  year_id  date_game  \
# 23811       11906  197103240LAL   NBA        0     1971  3/24/1971
# 23827       11914  197103260LAL   NBA        0     1971  3/26/1971
# 23898       11950  197104010LAL   NBA        0     1971   4/1/1971
# 23934       11968  197104060LAL   NBA        0     1971   4/6/1971
# 23970       11986  197104140LAL   NBA        0     1971  4/14/1971
# ...           ...           ...   ...      ...      ...        ...
# 118345      59173  201205120LAL   NBA        0     2012  5/12/2012
# 118367      59184  201205180LAL   NBA        0     2012  5/18/2012
# 118372      59187  201205190LAL   NBA        0     2012  5/19/2012
# 120926      60464  201304260LAL   NBA        0     2013  4/26/2013
# 120940      60471  201304280LAL   NBA        0     2013  4/28/2013
#
#         seasongame  is_playoffs team_id fran_id  pts      elo_i      elo_n  \
# 23811           83            1     LAL  Lakers  100  1480.7465  1484.4449
# ...

# %%
df.query("is_playoffs == 1 & fran_id == 'Lakers' & game_location == 'H' & year_id >1970")['pts'].head(5)
# Out:
# 23811    100
# 23827    105
# 23898    115
# 23934    109
# 23970    118
# Name: pts, dtype: int64

# %% [markdown]
# # GROUPING AND AGGREGATING

# %%
df.head(5)
# Out:
#    gameorder       game_id lg_id  _iscopy  year_id  date_game  seasongame  \
# 0          1  194611010TRH   NBA        0     1947  11/1/1946           1
# 1          1  194611010TRH   NBA        1     1947  11/1/1946           1
# 2          2  194611020CHS   NBA        0     1947  11/2/1946           1
# 3          2  194611020CHS   NBA        1     1947  11/2/1946           2
# 4          3  194611020DTF   NBA        0     1947  11/2/1946           1
#
#    is_playoffs team_id  fran_id  pts      elo_i      elo_n  win_equiv opp_id  \
# 0            0     TRH  Huskies   66  1300.0000  1293.2767  40.294830    NYK
# 1            0     NYK   Knicks   68  1300.0000  1306.7233  41.705170    TRH
# 2            0     CHS    Stags   63  1300.0000  1309.6521  42.012257    NYK
# 3            0     NYK   Knicks   47  1306.7233  1297.0712  40.692783    CHS
# 4            0     DTF  Falcons   33  1300.0000  1279.6189  38.864048    WSC
#
# ...

# %%
df.groupby('fran_id')['pts'].mean()
# Out:
# fran_id
# Baltimore        79.698073
# Bombers          71.457831
# Bucks           103.700050
# Bulls           101.525192
# Capitols         76.931271
# Cavaliers        99.846719
# Celtics         104.466233
# Clippers        101.934905
# Colonels        111.625296
# Condors         115.446512
# Denver           77.709677
# Falcons          63.283333
# Floridians      112.654545
# Grizzlies        95.161738
# Hawks           101.805635
# Heat             96.627162
# Hornets          94.506711
# Huskies          66.583333
# Ironmen          61.233333
# Jazz            102.153305
# Jets             74.700000
# Kings           103.971689
# Knicks          100.970185
# Lakers          105.817397
# Magic            99.427277
# Mavericks       102.634915
# Nets            101.755723
# Nuggets         108.199029
# Olympians        81.078014
# Pacers          103.687722
# Packers          86.013889
# Pelicans         97.956522
# Pistons         101.373097
# Raptors          96.921665
# ...

# %%
df['game_location'].value_counts()
# Out:
# H    63138
# A    63138
# N       38
# Name: game_location, dtype: int64

# %%
df.groupby('game_location')['pts'].mean() #[] untuk munculin kolom mana yg mau muncul
# Out:
# game_location
# A    100.856616
# H    104.602395
# N    104.315789
# Name: pts, dtype: float64

# %%
grup = df.groupby('game_location')

# %%
grup.get_group('A')['pts'].mean()
# Out:
# 100.85661566726853

# %%
grup.get_group('H')['pts'].mean()
# Out:
# 104.60239475434761

# %%
df[(df['year_id']>2010)&(df['pts']>110)&(df['fran_id']=="Lakers")].groupby(['game_location','game_result'])[['pts']].mean() #.sort_values('pts', ascending=False).head(3)
# Out:
#                                   pts
# game_location game_result
# A             L            115.142857
#               W            114.480000
# H             L            117.888889
#               W            117.157895

# %% [markdown]
# # Columns Manipulation
# - define new columns
# - rename column
# - drop column

# %%
nba=df.copy()

# %%
nba
# Out:
#         gameorder       game_id lg_id  _iscopy  year_id  date_game  \
# 0               1  194611010TRH   NBA        0     1947  11/1/1946
# 1               1  194611010TRH   NBA        1     1947  11/1/1946
# 2               2  194611020CHS   NBA        0     1947  11/2/1946
# 3               2  194611020CHS   NBA        1     1947  11/2/1946
# 4               3  194611020DTF   NBA        0     1947  11/2/1946
# ...           ...           ...   ...      ...      ...        ...
# 126309      63155  201506110CLE   NBA        0     2015  6/11/2015
# 126310      63156  201506140GSW   NBA        0     2015  6/14/2015
# 126311      63156  201506140GSW   NBA        1     2015  6/14/2015
# 126312      63157  201506170CLE   NBA        0     2015  6/16/2015
# 126313      63157  201506170CLE   NBA        1     2015  6/16/2015
#
#         seasongame  is_playoffs team_id    fran_id  pts      elo_i      elo_n  \
# 0                1            0     TRH    Huskies   66  1300.0000  1293.2767
# ...

# %%
# create new column
nba['selisih'] = np.absolute(nba['pts'] - nba['opp_pts']) #absolute untuk hilangkan minus

# %%
nba.head(5)
# Out:
#    gameorder       game_id lg_id  _iscopy  year_id  date_game  seasongame  \
# 0          1  194611010TRH   NBA        0     1947  11/1/1946           1
# 1          1  194611010TRH   NBA        1     1947  11/1/1946           1
# 2          2  194611020CHS   NBA        0     1947  11/2/1946           1
# 3          2  194611020CHS   NBA        1     1947  11/2/1946           2
# 4          3  194611020DTF   NBA        0     1947  11/2/1946           1
#
#    is_playoffs team_id  fran_id  pts      elo_i      elo_n  win_equiv opp_id  \
# 0            0     TRH  Huskies   66  1300.0000  1293.2767  40.294830    NYK
# 1            0     NYK   Knicks   68  1300.0000  1306.7233  41.705170    TRH
# 2            0     CHS    Stags   63  1300.0000  1309.6521  42.012257    NYK
# 3            0     NYK   Knicks   47  1306.7233  1297.0712  40.692783    CHS
# 4            0     DTF  Falcons   33  1300.0000  1279.6189  38.864048    WSC
#
# ...

# %%
nba.rename(columns={'game_location' : 'loc', 'game_result':'result'
}, inplace=True) #columns terus pake dictionary , inplace untuk overwrite variabel

# %%
nba
# Out:
#         gameorder       game_id lg_id  _iscopy  year_id  date_game  \
# 0               1  194611010TRH   NBA        0     1947  11/1/1946
# 1               1  194611010TRH   NBA        1     1947  11/1/1946
# 2               2  194611020CHS   NBA        0     1947  11/2/1946
# 3               2  194611020CHS   NBA        1     1947  11/2/1946
# 4               3  194611020DTF   NBA        0     1947  11/2/1946
# ...           ...           ...   ...      ...      ...        ...
# 126309      63155  201506110CLE   NBA        0     2015  6/11/2015
# 126310      63156  201506140GSW   NBA        0     2015  6/14/2015
# 126311      63156  201506140GSW   NBA        1     2015  6/14/2015
# 126312      63157  201506170CLE   NBA        0     2015  6/16/2015
# 126313      63157  201506170CLE   NBA        1     2015  6/16/2015
#
#         seasongame  is_playoffs team_id    fran_id  pts      elo_i      elo_n  \
# 0                1            0     TRH    Huskies   66  1300.0000  1293.2767
# ...

# %%
nba.drop(['elo_i','elo_n'],axis=1, inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_12052/893464123.py in <module>
# ----> 1 nba.drop(['elo_i','elo_n'],axis=1, inplace=True)
#       2 nba.drop([1,5],axis=0)
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4904                 weight  1.0     0.8
#    4905         """
# -> 4906         return super().drop(
#    4907             labels=labels,
#    4908             axis=axis,
#
# ...

# %% [markdown]
# drop year 1947 dan team spesifik -query
# index kita salin jadikan list
# list sebagai input .drop axis=0

# %%
#program selisih pts dengan opp_pts per baris
#simpan hasil ke list kosong
#convert list jadi kolom
nba.iloc[:10]

hasil = []


for i in range (len(nba)):
    selisih = nba.iloc[i,10] - nba.iloc[i,14]  #iloc dengan menghitung kolom ke berapa
    hasil.append(selisih)

nba['teshasilloop']=hasil

# %%
nba
# Out:
#         gameorder       game_id lg_id  _iscopy  year_id  date_game  \
# 0               1  194611010TRH   NBA        0     1947  11/1/1946
# 1               1  194611010TRH   NBA        1     1947  11/1/1946
# 2               2  194611020CHS   NBA        0     1947  11/2/1946
# 3               2  194611020CHS   NBA        1     1947  11/2/1946
# 4               3  194611020DTF   NBA        0     1947  11/2/1946
# ...           ...           ...   ...      ...      ...        ...
# 126309      63155  201506110CLE   NBA        0     2015  6/11/2015
# 126310      63156  201506140GSW   NBA        0     2015  6/14/2015
# 126311      63156  201506140GSW   NBA        1     2015  6/14/2015
# 126312      63157  201506170CLE   NBA        0     2015  6/16/2015
# 126313      63157  201506170CLE   NBA        1     2015  6/16/2015
#
#         seasongame  is_playoffs team_id    fran_id  pts  win_equiv opp_id  \
# 0                1            0     TRH    Huskies   66  40.294830    NYK
# ...

# %%
nba.drop([x for x in range(1,5)],axis=0)
# Out:
#         gameorder       game_id lg_id  _iscopy  year_id  date_game  \
# 0               1  194611010TRH   NBA        0     1947  11/1/1946
# 5               3  194611020DTF   NBA        1     1947  11/2/1946
# 6               4  194611020PRO   NBA        1     1947  11/2/1946
# 7               4  194611020PRO   NBA        0     1947  11/2/1946
# 8               5  194611020STB   NBA        1     1947  11/2/1946
# ...           ...           ...   ...      ...      ...        ...
# 126309      63155  201506110CLE   NBA        0     2015  6/11/2015
# 126310      63156  201506140GSW   NBA        0     2015  6/14/2015
# 126311      63156  201506140GSW   NBA        1     2015  6/14/2015
# 126312      63157  201506170CLE   NBA        0     2015  6/16/2015
# 126313      63157  201506170CLE   NBA        1     2015  6/16/2015
#
#         seasongame  is_playoffs team_id       fran_id  pts  win_equiv opp_id  \
# 0                1            0     TRH       Huskies   66  40.294830    NYK
# ...
